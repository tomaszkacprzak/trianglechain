# %%
from trianglechain import TriangleChain
import numpy as np
# %load_ext autoreload
# %autoreload 2

# %%
samples = np.load('chain.npy')
lnprobs = np.load('lnprobs.npy')
labels = [r'$\Omega_m$', r'$S_8$', r'$A_1$']#r'$n$', r'$h$', r'$\Omega_b$', r'$A_1$',
          #r'$\delta_{z,1}$',r'$\delta_{z,2}$',r'$\delta_{z,3}$',r'$\delta_{z,4}$',r'$\delta_{z,5}$']

# %% [markdown]
# # Credible Intervals

# %%
#default 0.68
tri = TriangleChain(labels=labels, params=['omega_m', 'S8', 'A_IA'])
tri.contour_cl(samples, show_values=True);
# Out:
# 2022-07-21 11:26:42,882 - TriangleChain.py: 173 -    INFO - Computing bestfits and levels
# 100%|█████████████████████████████████████████████| 3/3 [00:01<00:00,  2.17it/s]
# 100%|█████████████████████████████████████████████| 3/3 [00:00<00:00, 14.27it/s]

# %%
tri = TriangleChain(labels=labels, params=['omega_m', 'S8', 'A_IA'])
tri.contour_cl(samples, show_values=True, credible_interval=0.95);
# Out:
# 2022-07-21 11:26:49,248 - TriangleChain.py: 173 -    INFO - Computing bestfits and levels
# 100%|█████████████████████████████████████████████| 3/3 [00:01<00:00,  2.25it/s]
# 100%|█████████████████████████████████████████████| 3/3 [00:00<00:00, 14.75it/s]

# %% [markdown]
# # Levels

# %%
#default highest density interval hdi
tri = TriangleChain(labels=labels, params=['omega_m', 'S8', 'A_IA'])
tri.contour_cl(samples, show_values=True);
# Out:
# 2022-07-21 11:27:04,502 - TriangleChain.py: 173 -    INFO - Computing bestfits and levels
# 100%|█████████████████████████████████████████████| 3/3 [00:01<00:00,  2.26it/s]
# 100%|█████████████████████████████████████████████| 3/3 [00:00<00:00, 14.58it/s]

# %%
tri = TriangleChain(labels=labels, params=['omega_m', 'S8', 'A_IA'])
tri.contour_cl(samples, show_values=True, levels_method = 'percentile');
# Out:
# 2022-07-21 11:27:09,696 - TriangleChain.py: 173 -    INFO - Computing bestfits and levels
# 100%|█████████████████████████████████████████████| 3/3 [00:01<00:00,  2.34it/s]
# 100%|█████████████████████████████████████████████| 3/3 [00:00<00:00, 14.70it/s]

# %%
tri = TriangleChain(labels=labels, params=['omega_m', 'S8', 'A_IA'])
tri.contour_cl(samples, show_values=True, levels_method = 'PJ_HPD', lnprobs=lnprobs); #requires lnprobs
# Out:
# 2022-07-21 11:27:15,096 - TriangleChain.py: 173 -    INFO - Computing bestfits and levels
# 100%|█████████████████████████████████████████████| 3/3 [00:01<00:00,  2.13it/s]
# 100%|█████████████████████████████████████████████| 3/3 [00:00<00:00, 14.56it/s]

# %% [markdown]
# # bestfit

# %%
#default mode
tri = TriangleChain(labels=labels, params=['omega_m', 'S8', 'A_IA'])
tri.contour_cl(samples, show_values=True);
# Out:
# 2022-07-21 11:27:18,621 - TriangleChain.py: 173 -    INFO - Computing bestfits and levels
# 100%|█████████████████████████████████████████████| 3/3 [00:01<00:00,  2.27it/s]
# 100%|█████████████████████████████████████████████| 3/3 [00:00<00:00, 14.59it/s]

# %%
tri = TriangleChain(labels=labels, params=['omega_m', 'S8', 'A_IA'])
tri.contour_cl(samples, show_values=True, bestfit_method='mean');
# Out:
# 2022-07-21 11:27:20,353 - TriangleChain.py: 173 -    INFO - Computing bestfits and levels
# 100%|█████████████████████████████████████████████| 3/3 [00:00<00:00, 19.73it/s]
# 100%|█████████████████████████████████████████████| 3/3 [00:00<00:00, 14.72it/s]

# %%
tri = TriangleChain(labels=labels, params=['omega_m', 'S8', 'A_IA'])
tri.contour_cl(samples, show_values=True, bestfit_method='median');
# Out:
# 2022-07-21 11:27:20,971 - TriangleChain.py: 173 -    INFO - Computing bestfits and levels
# 100%|█████████████████████████████████████████████| 3/3 [00:00<00:00, 18.81it/s]
# 100%|█████████████████████████████████████████████| 3/3 [00:00<00:00, 14.76it/s]

# %%
tri = TriangleChain(labels=labels, params=['omega_m', 'S8', 'A_IA'])
tri.contour_cl(samples, show_values=True, bestfit_method='best_sample', lnprobs=lnprobs);#requires lnprobs
# Out:
# 2022-07-21 11:27:21,543 - TriangleChain.py: 173 -    INFO - Computing bestfits and levels
# 100%|█████████████████████████████████████████████| 3/3 [00:00<00:00, 19.76it/s]
# 100%|█████████████████████████████████████████████| 3/3 [00:00<00:00, 14.41it/s]
