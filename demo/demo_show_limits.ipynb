# %%
from trianglechain import TriangleChain
import numpy as np
# %load_ext autoreload
# %autoreload 2

# %%
samples = np.load('chain.npy')
lnprobs = np.load('lnprobs.npy')
labels = [r'$\Omega_m$', r'$S_8$', r'$A_1$']#r'$n$', r'$h$', r'$\Omega_b$', r'$A_1$',
          #r'$\delta_{z,1}$',r'$\delta_{z,2}$',r'$\delta_{z,3}$',r'$\delta_{z,4}$',r'$\delta_{z,5}$']

# %% [markdown]
# # Credible Intervals

# %%
#default 0.68
tri = TriangleChain(labels=labels, params=['omega_m', 'S8', 'A_IA'])
tri.contour_cl(samples, show_values=True);
# Out:
# 2022-09-21 22:22:10,357 - TriangleChain.py: 217 -    INFO - Computing bestfits and levels
# ...
#   0%|          | 0/3 [00:00<?, ?it/s]

# %%
tri = TriangleChain(labels=labels, params=['omega_m', 'S8', 'A_IA'])
tri.contour_cl(samples, show_values=True, credible_interval=0.95);
# Out:
# 2022-09-21 22:22:12,349 - TriangleChain.py: 217 -    INFO - Computing bestfits and levels
# ...
#   0%|          | 0/3 [00:00<?, ?it/s]

# %% [markdown]
# # Levels

# %%
#default highest density interval hdi
tri = TriangleChain(labels=labels, params=['omega_m', 'S8', 'A_IA'])
tri.contour_cl(samples, show_values=True);
# Out:
# 2022-09-21 22:22:14,154 - TriangleChain.py: 217 -    INFO - Computing bestfits and levels
# ...
#   0%|          | 0/3 [00:00<?, ?it/s]

# %%
tri = TriangleChain(labels=labels, params=['omega_m', 'S8', 'A_IA'])
tri.contour_cl(samples, show_values=True, levels_method = 'percentile');
# Out:
# 2022-09-21 22:22:15,940 - TriangleChain.py: 217 -    INFO - Computing bestfits and levels
# ...
#   0%|          | 0/3 [00:00<?, ?it/s]

# %%
tri = TriangleChain(labels=labels, params=['omega_m', 'S8', 'A_IA'])
tri.contour_cl(samples, show_values=True, levels_method = 'PJ_HPD', lnprobs=lnprobs); #requires lnprobs
# Out:
# 2022-09-21 22:22:17,705 - TriangleChain.py: 217 -    INFO - Computing bestfits and levels
# ...
#   0%|          | 0/3 [00:00<?, ?it/s]

# %% [markdown]
# # bestfit

# %%
#default mode
tri = TriangleChain(labels=labels, params=['omega_m', 'S8', 'A_IA'])
tri.contour_cl(samples, show_values=True);
# Out:
# 2022-09-21 22:22:19,566 - TriangleChain.py: 217 -    INFO - Computing bestfits and levels
# ...
#   0%|          | 0/3 [00:00<?, ?it/s]

# %%
tri = TriangleChain(labels=labels, params=['omega_m', 'S8', 'A_IA'])
tri.contour_cl(samples, show_values=True, bestfit_method='mean');
# Out:
# 2022-09-21 22:22:21,410 - TriangleChain.py: 217 -    INFO - Computing bestfits and levels
# ...
#   0%|          | 0/3 [00:00<?, ?it/s]

# %%
tri = TriangleChain(labels=labels, params=['omega_m', 'S8', 'A_IA'])
tri.contour_cl(samples, show_values=True, bestfit_method='median');
# Out:
# 2022-09-21 22:22:22,056 - TriangleChain.py: 217 -    INFO - Computing bestfits and levels
# ...
#   0%|          | 0/3 [00:00<?, ?it/s]

# %%
tri = TriangleChain(labels=labels, params=['omega_m', 'S8', 'A_IA'])
tri.contour_cl(samples, show_values=True, bestfit_method='best_sample', lnprobs=lnprobs);#requires lnprobs
# Out:
# 2022-09-21 22:22:22,636 - TriangleChain.py: 217 -    INFO - Computing bestfits and levels
# ...
#   0%|          | 0/3 [00:00<?, ?it/s]
